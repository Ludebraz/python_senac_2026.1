# %% [markdown]
# # Desafio 3.2

# %%
nota1=float(input("Digite a primeira nota :"))
nota2= float(input("Digite a segunda nota :"))
nota3= float(input("Digite a terceira nota :"))

# %%
somatorio= nota1+nota2+nota3
media= somatorio/3

# %%
print(f"O valor médio das notas é {media}")
# Out:
# O valor médio das notas é 9.0

# %% [markdown]
# # Desafio 3.3

# %%
celsius= float(input("Digite a temperatura em graus °C :" ))

# %%
f= (celsius * (9/5))+32

# %%
print(f"O valor da temperaura{celsius}°C convertido é {F}°F")
# Out:
# O valor da temperaura24.54°C convertido é 76.172°F

# %%
raio=float(input("Digite o raio de um circulo"))

# %%
AreaDoCirculo= A=(3,14*(raio*raio))

# %%
print(f"A área do circulo é igual a {AreaDoCirculo}")
# Out:
# A área do circulo é igual a (3, 35000.0)

# %% [markdown]
# # Desafio 4

# %% [markdown]
# ## Desafio 4.1

# %% [markdown]
# ### 1️⃣ Peça ao usuário um número e diga se ele é positivo, negativo ou zero.

# %%
n=int(input("Digite um numero:"))

# %%
if n < 0:
    print(f"o número.:{n}:. é NEGATIVO")
elif n == 0:
    print(f"o número.:{n}:. é ZERO")
else:
        print(f"o número.:{n}:. é POSITIVO")
# Out:
# o número.:5:. é POSITIVO

# %% [markdown]
# ### 4️⃣ Faça um programa que peça um número e diga se ele é par ou ímpar.

# %%
numero=int(input("Digite um número:"))

# %%
if (numero == 0):
    print(f"O número {numero} é ZERO")
elif(numero%2 == 0):
    print(f"O número {numero} é par")
else:
    print(f"O número {numero} é impar")
# Out:
# O número 7 é impar

# %% [markdown]
# ## Desafio 4.7

# %% [markdown]
# ### 7️⃣ Desenvolva um programa que calcule o IMC de uma pessoa e exiba sua classificação.
#
#     Fórmula: IMC = peso / (altura ** 2).
#
#     Classificações: -- Abaixo de 18.5 → Abaixo do peso -- Entre 18.5 e 24.9 → Peso ideal -- Entre 25 e 29.9 → Sobrepeso -- Acima de 30 → Obesidade

# %%
peso=float(input("Digite o seu peso (kg):"))
altura=float(input("Digite a sua altura em (m)"))

# %%
imc= peso/(altura**2)

if imc<=18.5:
    print("Abaixo do peso")
elif imc <= 24.9:
    print("Peso Ideal")
elif imc <= 29.9:
    print("Sobrepeso")
else:
    print("obeso")
# Out:
# obeso
