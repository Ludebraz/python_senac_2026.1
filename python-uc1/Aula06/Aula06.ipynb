# %% [markdown]
# # Aula 06

# %%
indice=0

frutasT=("Limão","pera","Maca","Abacate","Laranja")

# %%
for indice in range(5) :
    print(f"Indice: {indice}")
# Out:
# Indice: 0
# Indice: 1
# Indice: 2
# Indice: 3
# Indice: 4

# %%
contador=0
while (contador <= 15):
    print(f"O valor do contador é .:{contador}:.")
    contador+=1
print("Fim!!!")
# Out:
# O valor do contador é .:0:.
# O valor do contador é .:1:.
# O valor do contador é .:2:.
# O valor do contador é .:3:.
# O valor do contador é .:4:.
# O valor do contador é .:5:.
# O valor do contador é .:6:.
# O valor do contador é .:7:.
# O valor do contador é .:8:.
# O valor do contador é .:9:.
# O valor do contador é .:10:.
# O valor do contador é .:11:.
# O valor do contador é .:12:.
# O valor do contador é .:13:.
# O valor do contador é .:14:.
# O valor do contador é .:15:.
# Fim!!!

# %%
i=0
while i<5:
    print(f"O valor de i é .:{i}:.")
    i+=1
# Out:
# O valor de i é .:0:.
# O valor de i é .:1:.
# O valor de i é .:2:.
# O valor de i é .:3:.
# O valor de i é .:4:.

# %%
matriz = [
    [1,2,3],
    ["A","B","C"],
    [4,"D",5]
]

# %%
print(matriz)
# Out:
# [[1, 2, 3], ['A', 'B', 'C'], [4, 'D', 5]]

# %%
for linha in matriz:
    print("[",end="")
    for elemento in linha:
        print (f"{elemento}", end=", ")
    print("]", end="")
    print()
print("Fim!")
# Out:
# [1, 2, 3, ]
# [A, B, C, ]
# [4, D, 5, ]
# Fim!

# %%
for i in range(10):
    if i == 5:
        break #Para loop quando i for 5
    if i % 2 == 0:
        continue #Pula números pares
    print(i)
# Out:
# 1
# 3

# %%
for i in range(3):
    print(i)
else:
    print("Loop Concluído!")
# Out:
# 0
# 1
# 2
# Loop Concluído!
