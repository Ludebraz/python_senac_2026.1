# %%
def soma(a, b):
    soma=a+b
    return soma

# %%
resultado=soma(22,31)
print(f"O resultado é.:{resultado:04d}:.")
# Out:
# O resultado é.:0053:.

# %%
def soma_2(n1,n2):
    soma = n1+n2
    print (soma)

# %%
soma_2(12.4,15)
# Out:
# 27.4

# %%
resposta=soma_2(12,50)
print(resposta)
# Out:
# 62
# None

# %%
def multiplicaçao(c,d):
    multiplicaçao=c*d
    return multiplicaçao

# %%
multiplicaçao(5,7)
# Out:
# 35

# %%
def potencia(numero, expoente):
    resultado=numero**expoente
    return resultado

# %%
n1=2
exp=8

print(potencia(expoente=exp,numero=n1 ))
# Out:
# 256

# %%
n2=5
exp=4
resultado=potencia(n2,exp)
resultado2=potencia(exp,n2)

# %%
print (f"{resultado}<>{resultado2}")
# Out:
# 625<>1024

# %%
def listar_nomes(*nomes):
    for nome in nomes:
        print(nome)

# %%
listar_nomes("Lude", "Aline", "Bryan")
# Out:
# Lude
# Aline
# Bryan
